# %% [markdown]
# # How to Speed up Pandas by 4x

# %%
# !pip install modin[ray]

# %% [markdown]
# ### Read in the data with Pandas

# %%
import pandas as pd

# %%
# %%time

df=pd.read_csv('/content/drive/MyDrive/Datasets/esea_master_dmg_demos.part2.csv')
df
# Out:
# CPU times: user 13.1 s, sys: 1.9 s, total: 15 s
# Wall time: 21.4 s

# %%
df
# Out:
#                             file  round  ...  vic_pos_x  vic_pos_y
# 0        esea_match_13818366.dem      1  ...  -299.9824  2220.1480
# 1        esea_match_13818366.dem      1  ...   271.5201  2097.4790
# 2        esea_match_13818366.dem      1  ...   909.0534  1543.7200
# 3        esea_match_13818366.dem      1  ...   704.7518  1579.3470
# 4        esea_match_13818366.dem      1  ...   254.4920  -691.1022
# ...                          ...    ...  ...        ...        ...
# 4546080  esea_match_13829173.dem     22  ... -1220.2790 -1279.4920
# 4546081  esea_match_13829173.dem     22  ... -1218.2490 -1275.2540
# 4546082  esea_match_13829173.dem     22  ... -1132.0250  -191.1473
# 4546083  esea_match_13829173.dem     22  ... -1373.8790  -931.7026
# 4546084  esea_match_13829173.dem     22  ... -1215.1200 -1089.2760
#
# [4546085 rows x 23 columns]

# %%
df.groupby('att_team')

# %%
# %%time

df.groupby('att_team').count()
# Out:
# CPU times: user 2.1 s, sys: 7.93 ms, total: 2.11 s
# Wall time: 2.11 s
#                          file    round  ...  vic_pos_x  vic_pos_y
# att_team                                ...
# --to be determined--      647      647  ...        647        647
# ALTERNATE aTTaX           791      791  ...        791        791
# BOOT-dS Letou             610      610  ...        610        610
# Cerus eSports             338      338  ...        338        338
# Chiefs                    823      823  ...        823        823
# Dynasty                   710      710  ...        710        710
# FlashGaming               660      660  ...        660        660
# Grayhound                 759      759  ...        759        759
# Ground Zero               720      720  ...        720        720
# Guerrilla Tactics         350      350  ...        350        350
# Legacy                    316      316  ...        316        316
# ...

# %% [markdown]
# ### Read in the data with Modin

# %%
import modin.pandas as md

# %%
# %%time

df1=md.read_csv('/content/drive/MyDrive/Datasets/esea_master_dmg_demos.part2.csv')
df1
# Out:
# CPU times: user 1 s, sys: 741 ms, total: 1.75 s
# Wall time: 17.4 s

# %%
df1
# Out:
#                             file  round  ...  vic_pos_x  vic_pos_y
# 0        esea_match_13818366.dem      1  ...  -299.9824  2220.1480
# 1        esea_match_13818366.dem      1  ...   271.5201  2097.4790
# 2        esea_match_13818366.dem      1  ...   909.0534  1543.7200
# 3        esea_match_13818366.dem      1  ...   704.7518  1579.3470
# 4        esea_match_13818366.dem      1  ...   254.4920  -691.1022
# ...                          ...    ...  ...        ...        ...
# 4546080  esea_match_13829173.dem     22  ... -1220.2790 -1279.4920
# 4546081  esea_match_13829173.dem     22  ... -1218.2490 -1275.2540
# 4546082  esea_match_13829173.dem     22  ... -1132.0250  -191.1473
# 4546083  esea_match_13829173.dem     22  ... -1373.8790  -931.7026
# 4546084  esea_match_13829173.dem     22  ... -1215.1200 -1089.2760
#
# [4546085 rows x 23 columns]

# %%
# %%time

df1.groupby('att_team').count()
# Out:
# CPU times: user 152 ms, sys: 31 ms, total: 183 ms
# Wall time: 5.31 s
#                          file    round  ...  vic_pos_x  vic_pos_y
# att_team                                ...
# --to be determined--      647      647  ...        647        647
# ALTERNATE aTTaX           791      791  ...        791        791
# BOOT-dS Letou             610      610  ...        610        610
# Cerus eSports             338      338  ...        338        338
# Chiefs                    823      823  ...        823        823
# Dynasty                   710      710  ...        710        710
# FlashGaming               660      660  ...        660        660
# Grayhound                 759      759  ...        759        759
# Ground Zero               720      720  ...        720        720
# Guerrilla Tactics         350      350  ...        350        350
# Legacy                    316      316  ...        316        316
# ...
